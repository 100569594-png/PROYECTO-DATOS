# %% [markdown]
# <a href="https://colab.research.google.com/github/100569594-png/PROYECTO-DATOS/blob/main/prueba.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Clonar tu repositorio (esto descarga tus carpetas data, src, etc.)
# !git clone https://github.com/100569594-png/PROYECTO-DATOS.git

# 2. Movernos a la carpeta del proyecto
# %cd PROYECTO-DATOS

# 3. Instalar las librerías que definiste en requirements.txt
# !pip install -r requirements.txt

# 4. Actualizar el código (por si alguien hizo cambios en los .py)
# !git pull
# Out:
# Cloning into 'PROYECTO-DATOS'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 29 (delta 9), reused 5 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (29/29), 7.71 KiB | 3.85 MiB/s, done.
# Resolving deltas: 100% (9/9), done.
# /content/PROYECTO-DATOS
# Already up to date.
